# %% [markdown]
# # KNN Classification Lab Task
# **Student Name:** Abubakar Awan
# **Course:** AI Lab
# **Task:** Performance Analysis of KNN Algorithm

# %%
# Import libraries
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.datasets import make_classification, load_iris

# -------------------------
# DATASET 1 (IRIS)
# -------------------------
iris = load_iris()

X1 = iris.data
y1 = iris.target

X1_train, X1_test, y1_train, y1_test = train_test_split(
    X1, y1, test_size=0.3, random_state=0
)

print("IRIS DATASET")

for k in [1,3,5,7]:

    model = KNeighborsClassifier(n_neighbors=k)

    model.fit(X1_train, y1_train)

    y_pred = model.predict(X1_test)

    acc = accuracy_score(y1_test, y_pred)

    print("K =",k,"Accuracy =",acc)


# -------------------------
# DATASET 2 (GENERATED DATA)
# changing samples, features, classes
# -------------------------
X2, y2 = make_classification(

    n_samples=300,      # number of samples changed
    n_features=5,       # number of features changed
    n_classes=3,        # number of classes changed
    n_clusters_per_class=1,
    random_state=0

)

X2_train, X2_test, y2_train, y2_test = train_test_split(
    X2, y2, test_size=0.3, random_state=0
)

print("\nGENERATED DATASET")

for k in [1,3,5,7]:

    model = KNeighborsClassifier(n_neighbors=k)

    model.fit(X2_train, y2_train)

    y_pred = model.predict(X2_test)

    acc = accuracy_score(y2_test, y_pred)

    print("K =",k,"Accuracy =",acc)
# Out:
# IRIS DATASET
# K = 1 Accuracy = 0.9777777777777777
# K = 3 Accuracy = 0.9777777777777777
# K = 5 Accuracy = 0.9777777777777777
# K = 7 Accuracy = 0.9777777777777777
#
# GENERATED DATASET
# K = 1 Accuracy = 0.8
# K = 3 Accuracy = 0.8222222222222222
# K = 5 Accuracy = 0.8
# K = 7 Accuracy = 0.8111111111111111
