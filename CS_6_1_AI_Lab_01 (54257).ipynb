# %%
print("Hello World")
# Out:
# Hello World

# %%
x = input("Enter your name")
print(x)
# Out:
# Enter your nameAbubakar Awan
# Abubakar Awan

# %%
name = input("Enter your friends name")
age = input("Enter your friends age")
interest = input("Enter your friends interest")
nationality = input("ENter your friends nationality")

print(name, age, interest, nationality)
# Out:
# Enter your friends nameShabbaz Shairf
# Enter your friends age23
# Enter your friends interestPiasa
# ENter your friends nationalityPakistani
# Shabbaz Shairf 23 Piasa Pakistani

# %%
num = int(input("Enter a number: "))

if (num % 2) == 0:
   print("It is Even")
else:
   print("It is Odd")
# Out:
# Enter a number: 3
# It is Odd

# %%
15/4
# Out:
# 3.75

# %%
15//4
# Out:
# 3

# %%
def greeting():

  num = int(input("Enter a number: "))

  if (num % 2) == 0:
    print("It is Even")
  else:
    print("It is Odd")

# %%
greeting()
# Out:
# Enter a number: 123
# It is Odd

# %%
def frienddetails():
    name = input("Enter your friends name")
    age = input("Enter your friends age")
    interest = input("Enter your friends interest")
    nationality = input("ENter your friends nationality")
    print(name, age, interest, nationality)
    print(name, age, interest, nationality)
    print(name, age, interest, nationality)
    print(name, age, interest, nationality)
    print(name, age, interest, nationality)

# %%
frienddetails()
# Out:
# Enter your friends nameALi
# Enter your friends age23
# Enter your friends interestpiasa
# ENter your friends nationalityPakistani
# ALi 23 piasa Pakistani
# ALi 23 piasa Pakistani
# ALi 23 piasa Pakistani
# ALi 23 piasa Pakistani
# ALi 23 piasa Pakistani

# %%
greeting = ("Aoa")

for i in range (0,10):
  print(greeting)
# Out:
# Aoa
# Aoa
# Aoa
# Aoa
# Aoa
# Aoa
# Aoa
# Aoa
# Aoa
# Aoa

# %%
num = int(input("Enter a number: "))

for i in range(1, 11):
   print(num, "*", i, "=", num * i)
# Out:
# Enter a number: 20
# 20 * 1 = 20
# 20 * 2 = 40
# 20 * 3 = 60
# 20 * 4 = 80
# 20 * 5 = 100
# 20 * 6 = 120
# 20 * 7 = 140
# 20 * 8 = 160
# 20 * 9 = 180
# 20 * 10 = 200

# %%
def is_prime(n):
    if n == 0 or n == 1:
        return 0
    else:
        for i in range(2, n):
            if n % i == 0:
                return 0
    return 1

# %%
x = int (input("Enter a number"))
if is_prime(x)==0:
    print ("number is not prime")
else :
    print("number is prime")
# Out:
# Enter a number6
# number is not prime

# %%
count = 1
for i in range(100):
    if is_prime(i) == 1:
        print(count, "\t", i)
        if count >= 20:
            break
        count += 1
# Out:
# 1 	 2
# 2 	 3
# 3 	 5
# 4 	 7
# 5 	 11
# 6 	 13
# 7 	 17
# 8 	 19
# 9 	 23
# 10 	 29
# 11 	 31
# 12 	 37
# 13 	 41
# 14 	 43
# 15 	 47
# 16 	 53
# 17 	 59
# 18 	 61
# 19 	 67
# 20 	 71

# %%
square = lambda x:x*x*x

# %%
for i in range (10):
  print (square(i))
# Out:
# 0
# 1
# 8
# 27
# 64
# 125
# 216
# 343
# 512
# 729
